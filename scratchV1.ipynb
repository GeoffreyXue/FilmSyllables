# %%
from src.SyllableVisualizer import SyllableVisualizer
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sv = SyllableVisualizer("test.txt")
sv.convert_and_save("output", "The Social Network")

# %%
from src.TranscriptScraper import TranscriptScraper

tr = TranscriptScraper()
tr.scrape("src/scraped", "The Social Network", r"https://imsdb.com/scripts/Social-Network,-The.html")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Geoffrey\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# 'src/scraped/The Social Network.txt'

# %%
from time import sleep
from src.SyllableVisualizer import SyllableVisualizer
from src.TranscriptScraper import TranscriptScraper
# %load_ext autoreload
# %autoreload 2

films_to_scrape = [
    ('The Social Network', r'https://imsdb.com/scripts/Social-Network,-The.html')
]

ts = TranscriptScraper()
paths = ts.scrape_films("scraped", films_to_scrape)

for i in range(len(paths)):
    sv = SyllableVisualizer(paths[i])
    sv.convert_and_save("output/v1", films_to_scrape[i][0])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Geoffrey\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# parsing...
# finished parsing. generating image...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Geoffrey\Documents\Projects\FilmMelody\scratchV1.ipynb Cell 5' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Geoffrey/Documents/Projects/FilmMelody/scratchV1.ipynb#ch0000004?line=13'>14</a> for i in range(len(paths)):
# ...

# %%
with open("src/scraped", "w", encoding="utf-8") as f:
